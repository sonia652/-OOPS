# %% [markdown]
# #ASSIGNMNET : PYTHON OOPS
#
# #QUESTION 1: What is Object-Oriented Programming (OOP) ?
#
# #. Object-Oriented Programming (OOP) is a programming style where programs are designed using objects, which combine data (attributes) and functions (methods) together.It focuses on encapsulation, inheritance, polymorphism, and abstraction to make code modular, reusable, and easier to manage.
#
# #QUESTION 2. What is a class in OOP ?
#
# #. A class in OOP is a blueprint or template for creating objects.It defines attributes (data) and methods (functions) that the objects created from it will have.
#
# #QUESTION 3 . What is an object in OOP ?
#
# #. An object in OOP is an instance of a class.It is a real-world entity that has data (attributes) and can perform actions (methods) defined by its class.
#
# #QUESTION 4 .What is the difference between abstraction and encapsulation?
#
# #.Abstraction = Hiding implementation
#
# #Encapsulation = Hiding data
#
# #QUESTION 5. What are dunder methods in Python ?
#
# #. Dunder methods (short for “double underscore” methods) are special built-in methods in Python that have double underscores before and after their names, like __init__, __str__, __add__.
#
# #Key Points
# 🔹 Also called magic methods or special methods
# 🔹 They define the behavior of objects for built-in operations
#
# Examples
# __init__(self) → Constructor method, called when object is created
#
# __str__(self) → Defines string representation when using print()
#
#
# #QUESTION 6.Explain the concept of inheritance in OOP ?
#
# #. Inheritance is a concept where a class (child/subclass) can inherit properties and methods from another class (parent/superclass).
#
# Key Points
# 🔹 Promotes code reusability
# 🔹 Allows child classes to use and extend functionalities of parent classes
# 🔹 Supports hierarchical relationships
#
#
# #QUESTION 7. What is polymorphism in OOP ?
#
# #.Polymorphism means “many forms”.
# It allows the same function or method name to behave differently based on the object that calls it.
#
# Key Points
# 🔹 Helps in using a single interface for different data types or classes
# 🔹 Achieved via:
#
# Method Overloading (same method name with different parameters)
#
# Method Overriding (child class redefines parent class method)
#
#
# #QUESTION 8 .How is encapsulation achieved in Python?
#
# #.ncapsulation in Python is achieved by restricting access to variables and methods to protect data from accidental modification. It involves binding data and methods together and controlling their access.
#
# Here’s how encapsulation is achieved in Python:
#
# Using access specifiers:
#
# Public members (default): accessible from anywhere.
#
# Protected members (single underscore _var) : intended to be accessed only within the class and its subclasses (still accessible outside, but by convention treated as protected).
#
# Private members (double underscore __var): not accessible directly outside the class due to name mangling.
#
# Example:
#
# python
# Copy
# Edit
# class Student:
#     def __init__(self, name, age):
#         self.name = name           # public variable
#         self._age = age            # protected variable
#         self.__grade = 'A'         # private variable
#
#     def get_grade(self):
#         return self.__grade        # public method to access private variable
#
# s = Student("John", 20)
#
# print(s.name)    # accessible
# print(s._age)    # accessible but should be treated as protected
# # print(s.__grade)  # AttributeError
#
# # Accessing private variable using name mangling
# print(s._Student__grade)  # prints 'A'
#
# print(s.get_grade())      # preferred way to access private variable
# ✅ Summary:
#
#
# #QUESTION 9. What is a constructor in Python ?
#
# #. A constructor is a special method __init__() in a class that initializes objects when they are created.
#
# ✔ Example:
#
# python
# Copy
# Edit
# class Student:
#     def __init__(self, name):
#         self.name = name
#
#
# #QUESTION 10 . What are class and static methods in Python?
#
# #.✅ Class method:
#
# Uses @classmethod.
#
# Takes cls as first parameter.
#
# Can access/modify class variables.
#
# ✅ Static method:
#
# Uses @staticmethod.
#
# Takes no self or cls.
#
# Cannot access class or instance data; used for utility functions.
#
# #QUESTION 11 .What is method overloading in Python?
#
# #. ✅ Method overloading:
# Having multiple methods with the same name but different parameters.
#
# 🔴 In Python:
# Not directly supported; achieved using default arguments or *args to handle different numbers/types of arguments.
#
# #QUESTION 12. What is method overriding in OOP?
#
# #.✅ Method overriding:
# When a subclass defines a method with the same name as in the parent class, replacing its behaviour.
#
# #QUESTION 13. What is a property decorator in Python?
#
# #. ✅ Property decorator (@property):
# Turns a method into an attribute-like getter, allowing you to access it without parentheses.
#
# #QUESTION 14.Why is polymorphism important in OOP?
#
# #. ✅ Importance of Polymorphism:
#
# Flexibility:
# Allows functions/methods to work with objects of different classes seamlessly.
#
# Code Reusability:
# Same interface can be used for different data types, reducing duplication.
#
# Simplifies Code:
# Enables writing generic code that works on parent class references but executes child class methods.
#
# Enhances Maintainability:
# Easier to extend and maintain code by adding new classes without changing existing code structure.
#
# #QUESTION 15.  What is an abstract class in Python?
#
# #. ✅ Abstract class:
# A class that cannot be instantiated and contains one or more abstract methods (methods without implementation), defined using the abc module.
#
# ✔ Used for:
# Providing a base for subclasses to implement abstract methods.
#
# #QUESTION 16. What are the advantages of OOP?
#
# #. ✅ Advantages of OOP:
#
# Modularity (organised code)
#
# Reusability (inheritance)
#
# Data security (encapsulation)
#
# Flexibility (polymorphism)
#
# Easy maintenance (structured and clear code)
#
# #QUESTION 17 . What is the difference between a class variable and an instance variable?
#
# #.
# ✅ Class variable:
# Shared by all objects of the class.
#
# ✅ Instance variable:
# Unique to each object (instance) of the class.
#
# #QUESTION 18. What is multiple inheritance in Python?
#
# #.
# ✅ Multiple inheritance:
# A class inherits from more than one parent class, combining their features.
#
# #QUESTION 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python ?
#
# #.
# ✅ __str__ :
# Returns a user-friendly string representation of the object (for print()).
#
# ✅ __repr__ :
# Returns an official string representation (for developers/debugging), used by repr(), and should be unambiguous.
#
# #QUESTION 20. What is the significance of the ‘super()’ function in Python?
#
# #.
# ✅ super() function:
# Used to call methods of the parent class, mainly in inheritance to access or extend parent class functionality.
#
# #QUESTION 21.  What is the significance of the __del__ method in Python?
#
# #.
# ✅ __del__ method:
# Called when an object is about to be destroyed (destructor), used for cleanup tasks like closing files or releasing resources.
#
# #QUESTION 22. What is the difference between @staticmethod and @classmethod in Python?
#
# #.
# ✅ @staticmethod:
#
# No self or cls parameter.
#
# Cannot access class or instance data.
#
# ✅ @classmethod:
#
# Takes cls as first parameter.
#
# Can access/modify class variables.
#
# #QUESTION 23 .How does polymorphism work in Python with inheritance ?
#
# #.
# ✅ Polymorphism with inheritance:
# Allows child classes to override parent class methods, so the same method name behaves differently depending on the object calling it.
#
# #QUESTION 24. What is method chaining in Python OOP?
#
# #.
# ✅ Method chaining:
# Calling multiple methods in one line by having each method return self.
#
# #QUESTION 25. What is the purpose of the __call__ method in Python?
#
# #.
# ✅ __call__ method:
# Makes an object callable like a function, allowing it to be called using parentheses.

# %%
 # PRACTICAL QUESTIONS#

 # QUESTION 1.  Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
that overrides the speak() method to print "Bark!".

class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# Testing
a = Animal()
a.speak()   # Output: Animal speaks

d = Dog()
d.speak()   # Output: Bark!

# %%
#QUESTION 2.  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both.

#.from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Circle class
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius * self.radius

# Rectangle class
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# Testing
c = Circle(5)
r = Rectangle(4, 6)

print("Circle area:", c.area())       # Output: Circle area: 78.54...
print("Rectangle area:", r.area())    # Output: Rectangle area: 24

# %%
#QUESTION 3. . Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute.

#. # Parent class
class Vehicle:
    def __init__(self, type):
        self.type = type

# Child class of Vehicle
class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

# Child class of Car (multi-level inheritance)
class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

# Testing
ecar = ElectricCar("Four Wheeler", "Tesla", "100 kWh")
print("Type:", ecar.type)          # Output: Type: Four Wheeler
print("Brand:", ecar.brand)        # Output: Brand: Tesla
print("Battery:", ecar.battery)    # Output: Battery: 100 kWh

# %%
#QUESTION 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
Sparrow and Penguin that override the fly() method.


#. # Base class
class Bird:
    def fly(self):
        print("Birds can fly")

# Derived class Sparrow
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky")

# Derived class Penguin
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly")

# Testing polymorphism
birds = [Sparrow(), Penguin()]

for bird in birds:
    bird.fly()

# %%
#QUESTION 5.Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
balance and methods to deposit, withdraw, and check balance.

#.
class BankAccount:
    def __init__(self, initial_balance):
        self.__balance = initial_balance   # private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Invalid deposit amount")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: {amount}")
        else:
            print("Insufficient balance or invalid amount")

    def check_balance(self):
        print(f"Current balance: {self.__balance}")

# %%
#QUESTION 6.  Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
and Piano that implement their own version of play().

#.
# Base class
class Instrument:
    def play(self):
        print("Instrument is playing")

# Derived class Guitar
class Guitar(Instrument):
    def play(self):
        print("Guitar is playing melodious tunes")

# Derived class Piano
class Piano(Instrument):
    def play(self):
        print("Piano is playing classical music")

# Testing runtime polymorphism
instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()

# %%
#QUESTION 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
method subtract_numbers() to subtract two numbers.

#.
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Testing
print("Addition:", MathOperations.add_numbers(10, 5))       # Output: Addition: 15
print("Subtraction:", MathOperations.subtract_numbers(10, 5))  # Output: Subtraction: 5

# %%
#QUESTION 8.  Implement a class Person with a class method to count the total number of persons created.

#.
class Person:
    count = 0   # class variable to keep track

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

# Testing
p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

print("Total persons created:", Person.total_persons())  # Output: 3

# %%
#QUESTION 9 .  Write a class Fraction with attributes numerator and denominator. Override the str method to display the
fraction as "numerator/denominator".

#.
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Testing
f = Fraction(3, 4)
print(f)   # Output: 3/4

# %%
#QUESTION 10 .Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
vectors.


#.
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Overloading + operator
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

# Testing
v1 = Vector(2, 3)
v2 = Vector(4, 5)
v3 = v1 + v2  # uses __add__

print("v1 + v2 =", v3)  # Output: v1 + v2 = (6, 8)

# %%
#QUESTION 11.  Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
{name} and I am {age} years old."

#.
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Testing
p = Person("Alice", 25)
p.greet()   # Output: Hello, my name is Alice and I am 25 years old.

# %%
#QUESTION 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
the average of the grades.

#.
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # list of grades

    def average_grade(self):
        if self.grades:
            return sum(self.grades) / len(self.grades)
        else:
            return 0

# Testing
s = Student("John", [85, 90, 78, 92])
print(f"{s.name}'s average grade:", s.average_grade())  # Output: John's average grade: 86.25

# %%
#QUESTION 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
area.

#.
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Testing
r = Rectangle()
r.set_dimensions(5, 4)
print("Area of rectangle:", r.area())  # Output: Area of rectangle: 20

# %%
#QUESTION 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
and hourly rate. Create a derived class Manager that adds a bonus to the salary

#.
# Base class
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

# Derived class
class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

# Testing
e = Employee(40, 200)
print("Employee salary:", e.calculate_salary())  # Output: 8000

m = Manager(40, 200, 5000)
print("Manager salary:

# %%
#QUESTION 15.  Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
calculates the total price of the product.

#.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# Testing
p = Product("Laptop", 50000, 2)
print(f"Total price of {p.name}: {p.total_price()}")  # Output: Total price of Laptop: 100000

# %%
#QUESTION 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
implement the sound() method

#.
from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

# Derived class Cow
class Cow(Animal):
    def sound(self):
        print("Cow says Moo")

# Derived class Sheep
class Sheep(Animal):
    def sound(self):
        print("Sheep says Baa")

# Testing
c = Cow()
s = Sheep()

c.sound()   # Output: Cow says Moo
s.sound()   # Output: Sheep says Baa

# %%
#QUESTION 17 . . Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
returns a formatted string with the book's details.


#.
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

# Testing
b = Book("The Alchemist", "Paulo Coelho", 1988)
print(b.get_book_info())  # Output: 'The Alchemist' by Paulo Coelho, published in 1988

# %%
#QUESTION 18.Create a class House with attributes address and price. Create a derived class Mansion that adds an
attribute number_of_rooms

#.
# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

# Testing
m = Mansion("123 Elite Street", 50000000, 10)
print("Address:", m.address)               # Output: 123 Elite Street
print("Price:", m.price)                   # Output: 50000000
print("Number of rooms:", m.number_of_rooms)  # Output: 10
